# %%
#@save
import collections
import hashlib
import math
import os
import random
import re
import shutil
import sys
import tarfile
import time
import zipfile
from collections import defaultdict
import pandas as pd
import requests
from IPython import display
from matplotlib import pyplot as plt
from matplotlib_inline import backend_inline

d2l = sys.modules[__name__]

# %%
#@save
import numpy as mp
import torch
import torchvision 
from PIL import Image
from torch import nn
from torch.nn import functional as F
from torch.utils import data
from torchvision import transforms

# %%
# %matplotlib inline
import random
import torch
from d2l import torch as d2l

def syncthentic_data(w,b,num_example):#@save
    """生成y=Xw+b+噪声"""
    X=torch.normal(0,1,(num_example,len(w)))
    #该函数返回从单独的正态分布中提取的随机数的张量，该正态分布的均值是mean，标准差是std,输出张量的形状是out
    y=torch.matmul(X,w)+b
    #matmul 返回两个张量的乘积
    y+=torch.normal(0,0.01,y.shape)
    return X,y.reshape(-1,1)
                              
true_w=torch.tensor([2,-3.4])
true_b=4.2
features,labels=syncthentic_data(true_w,true_b,1000)

print('features:',features[0],'\nlabels:',labels[0])

d2l.set_figsize()
d2l.plt.scatter(features[:,(1)].detach().numpy(),labels.detach().numpy(),1)
# Out:
# features: tensor([-0.4900,  1.0073])
# labels: tensor([-0.2121])

# %%
def data_iter(batch_size,features,labels):
    num_examples=len(features)
    indices=list(range(num_examples))
    #随机读取
    random.shuffle(indices)
    for i in range(0,num_examples,batch_size):
        batch_indices=torch.tensor(indices[i:min(i+batch_size,num_examples)])
        yield features[batch_indices],labels[batch_indices]

# %%
batch_size=10
for X,y in data_iter(batch_size,features,labels):
    print(X,'\n',y)
    break;
# Out:
# tensor([[ 0.4847,  0.0213],
#         [ 0.1260,  2.7573],
#         [-0.1117, -0.2395],
#         [-1.5095,  0.7134],
#         [ 0.1235,  0.7859],
#         [ 0.1692,  0.5535],
#         [-0.0243,  0.6542],
#         [-1.5228, -1.1268],
#         [ 0.4339,  2.6308],
#         [-1.5921, -0.4853]])
#  tensor([[ 5.0932],
#         [-4.9251],
#         [ 4.8044],
#         [-1.2543],
#         [ 1.7770],
#         [ 2.6540],
#         [ 1.9240],
#         [ 4.9958],
#         [-3.8756],
#         [ 2.6761]])
